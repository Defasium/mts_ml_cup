# %% [markdown]
# ## Импорт библиотек

# %%
import pandas as pd
import numpy as np
import gzip
import os
import sys
from bs4 import BeautifulSoup
from tqdm.auto import tqdm
from multiprocessing.pool import Pool
import re
import pickle
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from scipy.sparse import csr_matrix
from sklearn.preprocessing import Normalizer

# %% [markdown]
# ## Загрузка файлов

# %%
def worker(file):
    try:
        with gzip.open('simwebhtml/%s'%file, 'rb') as f:
            page_source = f.read().decode('utf-8')
        soup = BeautifulSoup(page_source, 'html.parser')
        info = soup.find(id='demographics').text
        domain = file[:-3]
        good_file = 'wa-demographics__age-data-label' in page_source
        return (domain, soup.find_all('meta')[3].get('content', ''), info, good_file)
    except Exception as e:
        e = sys.exc_info()
        if isinstance(e[0], KeyboardInterrupt):
            return None
        return None


info = []
with Pool(8) as pool:
    files = os.listdir('simwebhtml')
    pbar = tqdm(total = len(files))
    for result in pool.imap(worker, files):
        if result is None: continue
        info.append(
            result
        )
        pbar.update(1)
# Out:
#   0%|          | 0/18845 [00:00<?, ?it/s]

# %% [markdown]
# ## Получение категории и рейтинга сайта

# %%
regex = re.compile(
    r'^([\w\d-]*\.[\w\d-]*) is ranked #(\d+) in the ([\w\s\>-]+) category and #(\d+) Globally.*$'
)

meta_info = []
for x in tqdm(info):
    res = regex.findall(x[1].replace('&', 'and'))[0]
    assert len(res) == 4
    (domain, top_cat, cat, top_all) = res
    meta_info.append((domain, int(top_cat), cat.strip(), int(top_all)))

meta_info
# Out:
#   0%|          | 0/17923 [00:00<?, ?it/s]
# [('turbopages.org', 1, 'News and Media Publishers', 34),
#  ('apest.ru', 8122, 'Health', 2792966),
#  ('med-tutorial.ru', 1925, 'Health > Health - Other', 737413),
#  ('mister-office.ru',
#   818,
#   'Computers Electronics and Technology > Computers Electronics and Technology - Other',
#   366845),
#  ('animedub.ru', 58, 'Arts and Entertainment > Animation and Comics', 65687),
#  ('vibir.ru',
#   1047,
#   'Computers Electronics and Technology > Telecommunications',
#   630900),
#  ('gp91.ru', 5023, 'Health > Health - Other', 2423137),
#  ('4eva.ru', 3551, 'News and Media Publishers', 1487585),
#  ('obzor.io', 9231, 'News and Media Publishers', 6174242),
#  ('nntv.tv', 4528, 'News and Media Publishers', 2120224),
#  ('raspisanie-autobusov.ru', 95, 'Reference Materials > Maps', 721972),
#  ('anyamashka.ru',
#   0,
#   'Arts and Entertainment > Arts and Entertainment - Other',
#   0),
#  ('policeiskiisrublevki.ru',
#   967,
#   'Arts and Entertainment > Streaming and Online TV',
#   484405),
#  ('egida.by', 26, 'Pets and Animals > Pets', 642932),
#  ('usa.one', 3277, 'News and Media Publishers', 338313),
#  ('donbasstoday.ru', 351, 'News and Media Publishers', 74526),
#  ('pleer.ru',
#   9,
#   'Computers Electronics and Technology > Consumer Electronics',
#   25704),
#  ('kitabi.ru',
#   18,
#   'Reference Materials > Public Records and Directories',
#   184949),
#  ('1pokopcheniyu.ru', 719, 'Food and Drink > Cooking and Recipes', 1140591),
#  ('mygrind.ru', 557, 'Games > Video Games Consoles and Accessories', 161250),
#  ('wasd.tv', 148, 'Games > Video Games Consoles and Accessories', 52131),
#  ('temaretik.com',
#   176,
#   'Computers Electronics and Technology > Computers Electronics and Technology - Other',
#   86057),
#  ('inkhunter.tattoo', 1122, 'Lifestyle > Beauty and Cosmetics', 1002048),
#  ('banquettes.ru',
#   110,
#   'Community and Society > Holidays and Seasonal Events',
#   2370985),
#  ('com.ua',
#   4553,
#   'Computers Electronics and Technology > Computers Electronics and Technology - Other',
#   6420396),
#  ('alchemer.com',
#   3,
#   'Business and Consumer Services > Marketing and Advertising',
#   2984),
#  ('onlain-multiki.ru',
#   162,
#   'Arts and Entertainment > Animation and Comics',
#   189019),
#  ('2map.su', 92, 'Reference Materials > Maps', 533089),
#  ('mirtesen.ru', 39, 'News and Media Publishers', 4739),
#  ('vsepredohraniteli.ru', 121, 'Vehicles > Vehicles - Other', 100238),
#  ('booksee.org', 480, 'Science and Education > Libraries and Museums', 369565),
#  ('sketchtattoo.ru',
#   8889,
#   'Arts and Entertainment > Arts and Entertainment - Other',
#   14587343),
#  ('pg11.ru', 652, 'News and Media Publishers', 127897),
#  ('pripravit.ru', 1832, 'Health > Health - Other', 904267),
#  ('beautyart.pro', 1549, 'Health > Health - Other', 831124),
#  ('detskysad.com', 67, 'Health > Childrens Health', 753170),
#  ('popcake.tv',
#   30,
#   'Arts and Entertainment > Arts and Entertainment - Other',
#   25921),
#  ('mail.ru', 1, 'Computers Electronics and Technology > Email', 31),
#  ('realmehelp.com',
#   546,
#   'Computers Electronics and Technology > Telecommunications',
#   620052),
#  ('multi-mama.ru', 377, 'Science and Education > Education', 139245),
#  ('tvzvezda.ru', 84, 'News and Media Publishers', 13079),
#  ('doktor.ru', 0, 'Health > Health - Other', 0),
#  ('dom-voprosov.ru',
#   1520,
#   'Computers Electronics and Technology > Telecommunications',
#   1099118),
#  ('mendeleevskyi.ru', 2173, 'News and Media Publishers', 815621),
#  ('uborka-v-dome.ru', 1422, 'Food and Drink > Cooking and Recipes', 3183137),
#  ('auto.ru', 3, 'Vehicles > Vehicles - Other', 1005),
#  ('ipleer.com', 3686, 'Arts and Entertainment > Music', 168158),
#  ('tsargrad.tv', 14, 'News and Media Publishers', 1641),
#  ('realbig.media',
#   2779,
#   'Computers Electronics and Technology > Computers Electronics and Technology - Other',
#   1610631),
#  ('guzei.com', 664, 'Arts and Entertainment > Music', 240066),
#  ('mtz-80.ru', 4994, 'Vehicles > Vehicles - Other', 1489781),
#  ('mosaica.ru', 393, 'News and Media Publishers', 81044),
#  ('steaklovers.menu', 57, 'Food and Drink > Cooking and Recipes', 153786),
#  ('litlib.net', 42, 'Arts and Entertainment > Books and Literature', 18648),
#  ('filgroup.ru',
#   1076,
#   'Arts and Entertainment > Streaming and Online TV',
#   509367),
#  ('extraman.ru', 2959, 'Adult', 758013),
#  ('turbopages.org', 1, 'News and Media Publishers', 34),
#  ('bezformata.com', 133, 'News and Media Publishers', 26778),
#  ('lagged.com', 135, 'Games > Video Games Consoles and Accessories', 11640),
#  ('antiagent.ru', 603, 'Home and Garden', 415426),
#  ('yardelfin.ru',
#   1119,
#   'Travel and Tourism > Travel and Tourism - Other',
#   1228150),
#  ('runarium.ru',
#   1640,
#   'Arts and Entertainment > Books and Literature',
#   2341857),
#  ('media-dad.com', 0, 'News and Media Publishers', 0),
#  ('wikireading.ru', 1, 'Science and Education > Social Sciences', 22610),
#  ('sp-smena.ru', 1592, 'Home and Garden > Gardening', 5387630),
#  ('joobix.ru', 42, 'Jobs and Career > Jobs and Employment', 180632),
#  ('narutoplanet.ru',
#   66,
#   'Arts and Entertainment > Animation and Comics',
#   59280),
#  ('31tv.ru', 1681, 'News and Media Publishers', 565384),
#  ('animegid.online',
#   272,
#   'Arts and Entertainment > Animation and Comics',
#   196544),
#  ('ampproject.org',
#   23,
#   'Computers Electronics and Technology > Programming and Developer Software',
#   11082),
#  ('sputnik.kz', 36, 'News and Media Publishers', 65723),
#  ('pandia.ru',
#   3,
#   'Science and Education > Science and Education - Other',
#   30311),
#  ('turbopages.org', 1, 'News and Media Publishers', 34),
#  ('kartinkiprazdnik.ru', 0, 'Arts and Entertainment > Humor', 0),
#  ('livejournal.com',
#   7,
#   'Computers Electronics and Technology > Social Media Networks',
#   642),
#  ('rutv.ru',
#   3823,
#   'Arts and Entertainment > Streaming and Online TV',
#   5392253),
#  ('pluggedin.ru', 101, 'Games > Video Games Consoles and Accessories', 37590),
#  ('10film.top',
#   3261,
#   'Arts and Entertainment > Streaming and Online TV',
#   3723931),
#  ('dogsecrets.ru', 743, 'Pets and Animals > Pets', 2717857),
#  ('starwars-galaxy.ru',
#   677,
#   'Arts and Entertainment > Books and Literature',
#   930160),
#  ('golovanameste.ru', 0, 'News and Media Publishers', 0),
#  ('krovli-zabori.ru',
#   27481,
#   'Heavy Industry and Engineering > Construction and Maintenance',
#   14894473),
#  ('loveread.club',
#   396,
#   'Arts and Entertainment > Books and Literature',
#   435514),
#  ('aif.ru', 19, 'News and Media Publishers', 2038),
#  ('ros-spravka.ru', 378, 'Law and Government', 302807),
#  ('dogworry.ru', 565, 'Pets and Animals > Pet Food and Supplies', 6494705),
#  ('webcam-resorts.ru',
#   2867,
#   'Travel and Tourism > Travel and Tourism - Other',
#   3583893),
#  ('beauty-around.com',
#   745,
#   'Arts and Entertainment > Streaming and Online TV',
#   126090),
#  ('fandom.com',
#   1,
#   'Arts and Entertainment > Arts and Entertainment - Other',
#   50),
#  ('bosfera.ru', 693, 'Finance > Finance - Other', 944509),
#  ('metr12.ru', 4305, 'News and Media Publishers', 1957657),
#  ('rd17.ru', 244, 'Health > Womens Health', 4620008),
#  ('glav-zaim.ru', 97, 'Finance > Financial Planning and Management', 150386),
#  ('glavny.tv', 52, 'Arts and Entertainment > Streaming and Online TV', 19284),
#  ('rbc.ru', 2, 'News and Media Publishers', 275),
#  ('walking-dead.me',
#   1251,
#   'Arts and Entertainment > Streaming and Online TV',
#   815641),
#  ('skolkomasla.ru', 5310, 'Vehicles > Vehicles - Other', 304970),
#  ('nordstroymarket.ru',
#   0,
#   'Heavy Industry and Engineering > Construction and Maintenance',
#   0),
#  ('manga-chan.me', 44, 'Arts and Entertainment > Animation and Comics', 48584),
#  ('ligainternet.ru',
#   2960,
#   'Computers Electronics and Technology > Computers Electronics and Technology - Other',
#   1496345),
#  ('ncpz.ru', 76, 'Health > Mental Health', 1037149),
#  ('biysk-tv.ru',
#   2778,
#   'Computers Electronics and Technology > Consumer Electronics',
#   3743813),
#  ('prihod.ru', 88, 'Community and Society > Faith and Beliefs', 172538),
#  ('napublic.com',
#   3129,
#   'Arts and Entertainment > Streaming and Online TV',
#   814035),
#  ('mamavet.ru', 271, 'Pets and Animals > Pets', 555340),
#  ('fandom.com',
#   1,
#   'Arts and Entertainment > Arts and Entertainment - Other',
#   50),
#  ('piteika.com', 209, 'Health > Alternative and Natural Medicine', 2803314),
#  ('hh.ru', 1, 'Jobs and Career > Jobs and Employment', 525),
#  ('ladyelena.ru', 35, 'Food and Drink > Cooking and Recipes', 97144),
#  ('turbopages.org', 1, 'News and Media Publishers', 34),
#  ('mugp-nv.ru', 4665, 'Health > Health - Other', 2120169),
#  ('pravozhil.com', 639, 'Law and Government > Legal', 2363485),
#  ('vse-zadarma.ru',
#   551,
#   'eCommerce and Shopping > eCommerce and Shopping - Other',
#   425775),
#  ('turbopages.org', 1, 'News and Media Publishers', 34),
#  ('kinoroom.link', 0, 'Arts and Entertainment > Streaming and Online TV', 0),
#  ('abcbiznes.ru',
#   201,
#   'Business and Consumer Services > Business Services',
#   843514),
#  ('trv-science.ru', 3755, 'News and Media Publishers', 690645),
#  ('slovopoisk.ru', 14, 'Pets and Animals > Pets', 173765),
#  ('regtorg.ru', 111, 'eCommerce and Shopping', 84891),
#  ('ura.news', 13, 'News and Media Publishers', 1511),
#  ('tekstovnet.ru', 1604, 'Arts and Entertainment > Music', 700849),
#  ('kladsovetov.ru', 1354, 'Law and Government > Legal', 4850389),
#  ('glavred.info', 34, 'News and Media Publishers', 14464),
#  ('telegram-plus.ru',
#   479,
#   'Computers Electronics and Technology > Social Media Networks',
#   681418),
#  ('turbopages.org', 1, 'News and Media Publishers', 34),
#  ('omnidesk.ru',
#   363,
#   'Computers Electronics and Technology > Computers Electronics and Technology - Other',
#   153532),
#  ('rmnt.ru',
#   80,
#   'Heavy Industry and Engineering > Construction and Maintenance',
#   259697),
#  ('turbopages.org', 1, 'News and Media Publishers', 34),
#  ('turbopages.org', 1, 'News and Media Publishers', 34),
#  ('tossy.ru', 1938, 'Lifestyle > Fashion and Apparel', 2314487),
#  ('reddit.com',
#   4,
#   'Computers Electronics and Technology > Social Media Networks',
#   19),
#  ('imo.im',
#   37,
#   'Computers Electronics and Technology > Search Engines',
#   49597),
#  ('lost-film-tv.ru',
#   648,
#   'Arts and Entertainment > Streaming and Online TV',
#   330360),
#  ('belgorodtv.ru', 3061, 'News and Media Publishers', 1132543),
#  ('com.ua',
#   4553,
#   'Computers Electronics and Technology > Computers Electronics and Technology - Other',
#   6420396),
#  ('atelierkorona.ru', 734, 'Hobbies and Leisure > Crafts', 4691392),
#  ('tubing-park.ru', 3852, 'Sports > Sports - Other', 7341261),
#  ('pandaland.kz', 32, 'Arts and Entertainment > Performing Arts', 418798),
#  ('super.ru', 294, 'News and Media Publishers', 44493),
#  ('umnica-krasavica.ru',
#   1538,
#   'Arts and Entertainment > Arts and Entertainment - Other',
#   1850058),
#  ('vodi.su', 3703, 'Vehicles > Vehicles - Other', 1484624),
#  ('turbopages.org', 1, 'News and Media Publishers', 34),
#  ('punkty-priema.ru',
#   67,
#   'Reference Materials > Public Records and Directories',
#   954499),
#  ('turbopages.org', 1, 'News and Media Publishers', 34),
#  ('xcartpro.com', 762, 'News and Media Publishers', 94424),
#  ('amdm.ru', 10, 'Arts and Entertainment > Music', 9002),
#  ('stroyres.net',
#   1816,
#   'Heavy Industry and Engineering > Construction and Maintenance',
#   838557),
#  ('sdamgia.ru', 5, 'Science and Education > Education', 2175),
#  ('x-tattoo.ru',
#   875,
#   'Arts and Entertainment > Arts and Entertainment - Other',
#   677118),
#  ('byrut.org', 10, 'Games > Video Games Consoles and Accessories', 2997),
#  ('oboitd.ru', 1339, 'Home and Garden > Home and Garden - Other', 1175780),
#  ('mirzspb.ru', 3020, 'Health > Health - Other', 2118874),
#  ('fratria.ru', 148, 'Sports > Soccer', 1004876),
#  ('maslocar.com', 3339, 'Vehicles > Vehicles - Other', 242307),
#  ('appsample.com', 191, 'Games > Video Games Consoles and Accessories', 12727),
#  ('grozny.tv', 2249, 'News and Media Publishers', 416895),
#  ('paralymp.ru', 926, 'Sports > Sports - Other', 1459581),
#  ('2ip.ru',
#   41,
#   'Computers Electronics and Technology > Computers Electronics and Technology - Other',
#   15287),
#  ('edaetoprosto.ru', 2489, 'Food and Drink > Cooking and Recipes', 14694712),
#  ('totoptool.ru',
#   176,
#   'Computers Electronics and Technology > Social Media Networks',
#   2455628),
#  ('rybalke.net', 3876, 'Vehicles > Vehicles - Other', 912736),
#  ('turbopages.org', 1, 'News and Media Publishers', 34),
#  ('rusolymp.ru',
#   372,
#   'Home and Garden > Home Improvement and Maintenance',
#   2661986),
#  ('nspu.ru', 536, 'Science and Education > Education', 231442),
#  ('womanmirror.ru', 798, 'Lifestyle > Beauty and Cosmetics', 1435529),
#  ('spbtv.com',
#   177,
#   'Computers Electronics and Technology > Programming and Developer Software',
#   131362),
#  ('comp-doma.ru',
#   211,
#   'Computers Electronics and Technology > Social Media Networks',
#   431113),
#  ('turbopages.org', 1, 'News and Media Publishers', 34),
#  ('ffn2j2jyr7b7uc44uk.buzz', 0, 'Unknown', 10865544),
#  ('muztrack.net', 5191, 'Arts and Entertainment > Music', 1621416),
#  ('ezoterica.club', 0, 'Community and Society > Faith and Beliefs', 0),
#  ('svetacdn.in', 0, 'Arts and Entertainment > Streaming and Online TV', 0),
#  ('expressaero.ru', 399, 'Travel and Tourism > Air Travel', 3173733),
#  ('ngs.ru', 45, 'News and Media Publishers', 5724),
#  ('darktexts.ru', 228, 'Arts and Entertainment > Music', 218199),
#  ('blotos.ru', 90, 'Health > Pharmacy', 415613),
#  ('i58.ru', 108, 'eCommerce and Shopping > Classifieds', 472617),
#  ('bezformata.com', 133, 'News and Media Publishers', 26778),
#  ('adriver.ru', 0, 'Computers Electronics and Technology', 0),
#  ('turbopages.org', 1, 'News and Media Publishers', 34),
#  ('arbitr-laptova.ru',
#   555,
#   'Law and Government > Law and Government - Other',
#   2506031),
#  ('vringe.com', 4, 'Sports > Boxing', 62434),
#  ('sampo.ru',
#   54,
#   'Computers Electronics and Technology > Telecommunications',
#   85221),
#  ('bizakon.ru', 2482, 'Law and Government > Legal', 7863516),
#  ('ru-an.info', 306, 'News and Media Publishers', 51726),
#  ('fincalculator.ru',
#   110,
#   'Finance > Financial Planning and Management',
#   137766),
#  ('aktsport.ru', 52, 'Sports > Extreme Sports', 3755151),
#  ('maslogid.com', 2235, 'Vehicles > Vehicles - Other', 835584),
#  ('123ru.market',
#   3485,
#   'Business and Consumer Services > Real Estate',
#   12644293),
#  ('ixbt.video',
#   2219,
#   'Computers Electronics and Technology > Computer Hardware',
#   7115656),
#  ('skachat-dlya-android.ru',
#   766,
#   'Computers Electronics and Technology > Computers Electronics and Technology - Other',
#   264101),
#  ('aport.ru', 16, 'eCommerce and Shopping > Price Comparison', 701017),
#  ('minusovka.pro', 466, 'Arts and Entertainment > Music', 493240),
#  ('2samogona.ru', 289, 'Vehicles > Vehicles - Other', 248168),
#  ('agpu.net', 2528, 'Science and Education > Education', 1404121),
#  ('turbopages.org', 1, 'News and Media Publishers', 34),
#  ('flatinfo.ru', 50, 'Home and Garden', 80431),
#  ('morsmusic.org', 8, 'Arts and Entertainment > Music', 7378),
#  ('beetlestop.ru',
#   821,
#   'Computers Electronics and Technology > Social Media Networks',
#   1513306),
#  ('yanashla.com',
#   133,
#   'eCommerce and Shopping > eCommerce and Shopping - Other',
#   152091),
#  ('sprosivracha.com', 13, 'Health > Health - Other', 20289),
#  ('otdyhvkarelii.ru',
#   1750,
#   'Travel and Tourism > Travel and Tourism - Other',
#   2153555),
#  ('24video.net', 759, 'Adult', 120690),
#  ('viperson.ru', 921, 'News and Media Publishers', 239245),
#  ('equity.today', 176, 'Finance > Investing', 287220),
#  ('postupi.online', 61, 'Science and Education > Education', 26528),
#  ('ko44.ru', 2083, 'News and Media Publishers', 744756),
#  ('cian.ru', 1, 'Business and Consumer Services > Real Estate', 712),
#  ('turbopages.org', 1, 'News and Media Publishers', 34),
#  ('cattish.ru', 371, 'Pets and Animals > Pets', 461303),
#  ('vkbaron.ru',
#   823,
#   'Computers Electronics and Technology > Social Media Networks',
#   2136705),
#  ('counter-files.ru',
#   4036,
#   'Games > Video Games Consoles and Accessories',
#   15021544),
#  ('prmira.ru', 934, 'News and Media Publishers', 237820),
#  ('гдз.рф', 0, 'Unknown', 911266),
#  ('wikibotanika.ru', 484, 'Home and Garden > Gardening', 621395),
#  ('di7stero.com',
#   170,
#   'Computers Electronics and Technology > Search Engines',
#   207694),
#  ('info-stroyka.ru',
#   0,
#   'Home and Garden > Home Improvement and Maintenance',
#   0),
#  ('naturae.ru',
#   253,
#   'Reference Materials > Dictionaries and Encyclopedias',
#   1525739),
#  ('ecopol98.ru',
#   329,
#   'Heavy Industry and Engineering > Construction and Maintenance',
#   673439),
#  ('proprof.ru', 2674, 'Science and Education > Education', 1508493),
#  ('sibdepo.ru', 546, 'News and Media Publishers', 128875),
#  ('zoon.ru',
#   5,
#   'Arts and Entertainment > Arts and Entertainment - Other',
#   7040),
#  ('legallurist.ru', 4085, 'Law and Government > Legal', 9201992),
#  ('atol.ru',
#   297,
#   'Computers Electronics and Technology > Computers Electronics and Technology - Other',
#   163686),
#  ('the-geek.ru',
#   1395,
#   'Computers Electronics and Technology > Computers Electronics and Technology - Other',
#   399546),
#  ('iro23.ru', 698, 'Science and Education > Education', 329665),
#  ('mk-turkey.ru', 2249, 'Arts and Entertainment', 191653),
#  ('svoimi-rukami2.ru', 854, 'Hobbies and Leisure > Crafts', 5621290),
#  ('textru.ru', 1400, 'Science and Education > Education', 750451),
#  ('vesti.ua', 138, 'News and Media Publishers', 49743),
#  ('lermontov-lit.ru',
#   369,
#   'Science and Education > Libraries and Museums',
#   1815390),
#  ('nashbryansk.ru', 959, 'News and Media Publishers', 273211),
#  ('yablyk.com',
#   281,
#   'Computers Electronics and Technology > Computers Electronics and Technology - Other',
#   93639),
#  ('ekogradmoscow.ru', 5645, 'News and Media Publishers', 2559768),
#  ('grimm-all.ru',
#   742,
#   'Arts and Entertainment > Streaming and Online TV',
#   310863),
#  ('novostrojki-ekaterinburga.ru',
#   570,
#   'Home and Garden > Home and Garden - Other',
#   655456),
#  ('sib.fm', 264, 'News and Media Publishers', 52208),
#  ('vazhnoznat.com', 1801, 'News and Media Publishers', 408972),
#  ('xhcdn.com', 621, 'Adult', 7765),
#  ('ckolkoctoit.ru', 120, 'Pets and Animals > Pets', 660638),
#  ('allohastream.com',
#   6639,
#   'Computers Electronics and Technology > Computers Electronics and Technology - Other',
#   3780045),
#  ('ob11.ru', 8732, 'Health > Health - Other', 2334885),
#  ('maslohelp.ru', 301, 'Vehicles > Automotive Industry', 176970),
#  ('plus-forum.com',
#   2418,
#   'Business and Consumer Services > Marketing and Advertising',
#   14720065),
#  ('domru.ru',
#   106,
#   'Computers Electronics and Technology > Telecommunications',
#   164440),
#  ('hdstudio.org',
#   48,
#   'Arts and Entertainment > Streaming and Online TV',
#   13697),
#  ('katalogi-online.ru',
#   3355,
#   'Home and Garden > Home and Garden - Other',
#   2818830),
#  ('bezformata.com', 133, 'News and Media Publishers', 26778),
#  ('turbopages.org', 1, 'News and Media Publishers', 34),
#  ('emiclub.ru', 115, 'Health > Medicine', 664602),
#  ('nazvonok.info', 1415, 'Arts and Entertainment > Music', 1655260),
#  ('hitmotop.com', 2, 'Arts and Entertainment > Music', 1906),
#  ('tatar-inform.tatar', 3986, 'News and Media Publishers', 1742692),
#  ('pg12.ru', 461, 'News and Media Publishers', 94344),
#  ('dropi.ru', 985, 'Arts and Entertainment', 82459),
#  ('media-base.co', 0, 'Arts and Entertainment > Streaming and Online TV', 0),
#  ('promesyachnye.ru', 1376, 'Health > Health - Other', 775295),
#  ('samara.ru', 18990, 'News and Media Publishers', 15535932),
#  ('electroshemi.ru', 860, 'Vehicles > Vehicles - Other', 3486181),
#  ('bestlavka.ru', 404, 'Health > Health - Other', 293611),
#  ('versiya.info', 327, 'News and Media Publishers', 50210),
#  ('mega-grinn.ru',
#   1231,
#   'Arts and Entertainment > Arts and Entertainment - Other',
#   1551800),
#  ('dnpmag.com', 682, 'News and Media Publishers', 153613),
#  ('burdastyle.ru', 7, 'Lifestyle > Fashion and Apparel', 20489),
#  ('xiaoyi.com',
#   2709,
#   'Computers Electronics and Technology > Computers Electronics and Technology - Other',
#   264112),
#  ('vestnic.ru', 6, 'Hobbies and Leisure > Crafts', 80455),
#  ('turbopages.org', 1, 'News and Media Publishers', 34),
#  ('topster.plus', 186, 'Arts and Entertainment > Humor', 359666),
#  ('piramida-stroi.ru',
#   1927,
#   'Home and Garden > Home and Garden - Other',
#   9282324),
#  ('ulpol5.ru', 8758, 'Health > Health - Other', 2974066),
#  ('magnitola.info', 2051, 'Vehicles > Vehicles - Other', 2580415),
#  ('florioza.ru', 10487, 'Health > Health - Other', 6090400),
#  ('zakolduj.ru', 970, 'Community and Society > Faith and Beliefs', 1611144),
#  ('at.ua',
#   144,
#   'Computers Electronics and Technology > Computers Electronics and Technology - Other',
#   22637),
#  ('academic.ru',
#   6,
#   'Reference Materials > Dictionaries and Encyclopedias',
#   11026),
#  ('precedent.tv',
#   65,
#   'Law and Government > Law and Government - Other',
#   339392),
#  ('loginza.ru',
#   13079,
#   'Computers Electronics and Technology > Computers Electronics and Technology - Other',
#   5409276),
#  ('uk-parkovaya.ru', 106, 'Finance > Accounting and Auditing', 1164015),
#  ('picabox.ru',
#   2965,
#   'eCommerce and Shopping > eCommerce and Shopping - Other',
#   3016230),
#  ('tutu.ru', 1, 'Travel and Tourism > Travel and Tourism - Other', 1809),
#  ('otm-r.com',
#   354,
#   'Computers Electronics and Technology > Computers Electronics and Technology - Other',
#   389997),
#  ('izberbashmrdc.ru', 13365, 'Health > Health - Other', 7607024),
#  ('turbopages.org', 1, 'News and Media Publishers', 34),
#  ('listtopa.ru', 3088, 'News and Media Publishers', 1214931),
#  ('adgaterewards.com',
#   12,
#   'Computers Electronics and Technology > Advertising Networks',
#   24270),
#  ('krasymavto.ru', 11614, 'Vehicles > Vehicles - Other', 4643078),
#  ('sunlight.net', 1, 'Lifestyle > Jewelry and Luxury Products', 9754),
#  ('sadda.ru',
#   5543,
#   'Computers Electronics and Technology > Programming and Developer Software',
#   4145661),
#  ('retromap.ru', 18, 'Reference Materials > Maps', 76032),
#  ('101oblik.ru', 1603, 'Lifestyle > Fashion and Apparel', 1568514),
#  ('zagranguru.ru',
#   835,
#   'Law and Government > Law and Government - Other',
#   3949612),
#  ('kinosvami.ru',
#   298,
#   'Arts and Entertainment > Streaming and Online TV',
#   93341),
#  ('wedmak.online',
#   1012,
#   'Arts and Entertainment > Streaming and Online TV',
#   548100),
#  ('bydom.ru',
#   250,
#   'Heavy Industry and Engineering > Construction and Maintenance',
#   434181),
#  ('bezpalatki.ru',
#   344,
#   'Science and Education > Science and Education - Other',
#   1447367),
#  ('sms-mms-free.ru',
#   1061,
#   'Computers Electronics and Technology > Telecommunications',
#   979379),
#  ('profpipe.ru',
#   7237,
#   'Heavy Industry and Engineering > Construction and Maintenance',
#   4853957),
#  ('my-seriya.com',
#   7005,
#   'Arts and Entertainment > Streaming and Online TV',
#   7076769),
#  ('cgt24.ru', 14771, 'Vehicles > Vehicles - Other', 6657925),
#  ('kulinarenok.ru', 13, 'Food and Drink > Cooking and Recipes', 29593),
#  ('dostavka24.pro', 249, 'Food and Drink > Restaurants and Delivery', 6800679),
#  ('god-svadbi.ru',
#   132,
#   'Community and Society > Holidays and Seasonal Events',
#   3108916),
#  ('lifelib.info', 562, 'Health > Medicine', 2008698),
#  ('onliner.by', 1, 'News and Media Publishers', 1555),
#  ('nqi-russia.ru', 14817, 'Health > Health - Other', 8369023),
#  ('stavkibankov.ru',
#   1450,
#   'Finance > Financial Planning and Management',
#   4476662),
#  ('turksezon.net',
#   260,
#   'Arts and Entertainment > Streaming and Online TV',
#   54350),
#  ('gidgood.ru', 929, 'Lifestyle > Childcare', 2252034),
#  ('4cheat.ru', 876, 'Games > Video Games Consoles and Accessories', 216198),
#  ('cqkct.com', 0, 'Unknown', 258874),
#  ('hobiz.ru', 10380, 'Computers Electronics and Technology', 1317314),
#  ('turbopages.org', 1, 'News and Media Publishers', 34),
#  ('moluch.ru', 283, 'News and Media Publishers', 52009),
#  ('vipidei.com', 630, 'Food and Drink > Food and Drink - Other', 765020),
#  ('edu.ru', 1194, 'Science and Education > Education', 553395),
#  ('ex-hort.ru',
#   6478,
#   'Computers Electronics and Technology > Computers Electronics and Technology - Other',
#   1851526),
#  ('40nog.ru',
#   147,
#   'eCommerce and Shopping > eCommerce and Shopping - Other',
#   182317),
#  ('slovo.me',
#   1313,
#   'Computers Electronics and Technology > Computer Security',
#   6687404),
#  ('bezformata.com', 133, 'News and Media Publishers', 26778),
#  ('thg.ru',
#   104,
#   'Computers Electronics and Technology > Computer Hardware',
#   308269),
#  ('turbopages.org', 1, 'News and Media Publishers', 34),
#  ('nur24.ru', 1575, 'News and Media Publishers', 516449),
#  ('foto-recipes.ru', 563, 'Food and Drink > Cooking and Recipes', 807097),
#  ('ocomp.info',
#   78,
#   'Computers Electronics and Technology > Programming and Developer Software',
#   59574),
#  ('kkb2-kuban.ru', 3751, 'Health > Health - Other', 1789321),
#  ('newsua.ru', 574, 'News and Media Publishers', 167258),
#  ('politpuzzle.ru', 562, 'News and Media Publishers', 94876),
#  ('tsargrad.tv', 14, 'News and Media Publishers', 1641),
#  ('webkind.ru',
#   147,
#   'Computers Electronics and Technology > Search Engines',
#   342092),
#  ('zoon.ru',
#   5,
#   'Arts and Entertainment > Arts and Entertainment - Other',
#   7040),
#  ('uvelichit-chlen.com', 2294, 'Adult', 348757),
#  ('detionline.com', 12398, 'Science and Education > Education', 7664160),
#  ('turbopages.org', 1, 'News and Media Publishers', 34),
#  ('edemnayug.com',
#   6798,
#   'Travel and Tourism > Travel and Tourism - Other',
#   8456519),
#  ('ispolnitelnaya.ru',
#   146,
#   'Heavy Industry and Engineering > Construction and Maintenance',
#   217816),
#  ('kinogo.biz', 2, 'Arts and Entertainment > Streaming and Online TV', 2536),
#  ('hovels.info', 0, 'Unknown', 18089214),
#  ('avtobus-raspisanie.ru',
#   148,
#   'Travel and Tourism > Ground Transportation',
#   1030367),
#  ('deshovaya-apteka.ru', 7957, 'Health > Health - Other', 3118067),
#  ('patriarchia.ru', 34, 'Community and Society > Faith and Beliefs', 56819),
#  ('deti-online.com', 34, 'Science and Education > Education', 9341),
#  ('ss-p.ru', 1051, 'Home and Garden > Gardening', 3562038),
#  ('glav-dacha.ru', 81, 'Home and Garden > Home and Garden - Other', 127011),
#  ('yavitrina.ru',
#   50,
#   'eCommerce and Shopping > eCommerce and Shopping - Other',
#   64642),
#  ('lasl.ru', 2544, 'Adult', 813445),
#  ('firmsdata.ru',
#   90,
#   'Reference Materials > Public Records and Directories',
#   1512305),
#  ('vk-look.com',
#   1163,
#   'Computers Electronics and Technology > Social Media Networks',
#   4221645),
#  ('turbopages.org', 1, 'News and Media Publishers', 34),
#  ('rambler.ru', 3, 'News and Media Publishers', 286),
#  ('cian.ru', 1, 'Business and Consumer Services > Real Estate', 712),
#  ('tokzamer.ru',
#   424,
#   'Heavy Industry and Engineering > Construction and Maintenance',
#   457217),
#  ('rt-online.ru', 1163, 'Law and Government', 745307),
#  ('volgodonskgorod.ru',
#   1536,
#   'Law and Government > Law and Government - Other',
#   6432666),
#  ('flyings.guru', 285, 'Travel and Tourism > Air Travel', 1022215),
#  ('instagrabber.ru',
#   751,
#   'Computers Electronics and Technology > Social Media Networks',
#   2256912),
#  ('turbopages.org', 1, 'News and Media Publishers', 34),
#  ('moe-belgorod.ru', 2255, 'News and Media Publishers', 843660),
#  ('platki.ru', 105, 'Lifestyle > Fashion and Apparel', 139418),
#  ('5terka.com', 131, 'Science and Education > Education', 46549),
#  ('turbopages.org', 1, 'News and Media Publishers', 34),
#  ('terrameteo.ru', 1930, 'News and Media Publishers', 697635),
#  ('naperevoz.ru', 1665, 'Vehicles > Automotive Industry', 2204476),
#  ('viqeo.tv', 3825, 'News and Media Publishers', 675037),
#  ('mail.ru', 1, 'Computers Electronics and Technology > Email', 31),
#  ('kia-club.ru', 187, 'Vehicles > Vehicles - Other', 189054),
#  ('vesti.news', 2615, 'News and Media Publishers', 922394),
#  ('cooldj.club', 489, 'Arts and Entertainment > Music', 276687),
#  ('rf-sp.ru', 4341, 'Lifestyle', 1590579),
#  ('animefox.org', 45, 'Arts and Entertainment > Animation and Comics', 46305),
#  ('doctorhouse.tv',
#   1292,
#   'Arts and Entertainment > Streaming and Online TV',
#   875424),
#  ('hozobzor.ru', 2931, 'News and Media Publishers', 730459),
#  ('turbopages.org', 1, 'News and Media Publishers', 34),
#  ('wpoz.ru',
#   600,
#   'Arts and Entertainment > Arts and Entertainment - Other',
#   716894),
#  ('aif.ru', 19, 'News and Media Publishers', 2038),
#  ('kubsu.ru', 411, 'Science and Education > Education', 169703),
#  ('rbc.ru', 2, 'News and Media Publishers', 275),
#  ('урок.рф', 110, 'Science and Education > Education', 47262),
#  ('expertpobonusam.com',
#   807,
#   'Food and Drink > Food and Drink - Other',
#   1251986),
#  ('algal.online',
#   78,
#   'Hobbies and Leisure > Antiques and Collectibles',
#   535323),
#  ('present5.com', 320, 'Science and Education > Education', 116209),
#  ('politexpert.net', 213, 'News and Media Publishers', 34735),
#  ('lyrsense.com', 30, 'Arts and Entertainment > Music', 19011),
#  ('mnpcbt.ru', 4592, 'Health > Health - Other', 2246894),
#  ('iseptick.ru',
#   5065,
#   'Heavy Industry and Engineering > Construction and Maintenance',
#   3456493),
#  ('советуем-куда-поехать-отдыхать.рф',
#   3767,
#   'Travel and Tourism > Travel and Tourism - Other',
#   10964783),
#  ('yandex.ru', 1, 'Computers Electronics and Technology > Search Engines', 7),
#  ('fandom.com',
#   1,
#   'Arts and Entertainment > Arts and Entertainment - Other',
#   50),
#  ('protvonline.ru', 0, 'Arts and Entertainment > Streaming and Online TV', 0),
#  ('vesti-tver.ru', 1672, 'News and Media Publishers', 569289),
#  ('yastatic.net',
#   24,
#   'Computers Electronics and Technology > Search Engines',
#   43791),
#  ('vologda-poisk.ru', 591, 'News and Media Publishers', 121485),
#  ('tsargrad.tv', 14, 'News and Media Publishers', 1641),
#  ('aldebaran.ru', 117, 'Arts and Entertainment > Books and Literature', 61902),
#  ('twokarburators.ru', 209, 'Vehicles > Vehicles - Other', 186458),
#  ('alloeclub.com', 0, 'Unknown', 713138),
#  ('lubikamni.ru', 818, 'Lifestyle > Jewelry and Luxury Products', 3237790),
#  ('8sot.su',
#   59,
#   'Computers Electronics and Technology > Search Engines',
#   156196),
#  ('telecomdom.ru',
#   1267,
#   'Computers Electronics and Technology > Telecommunications',
#   1740420),
#  ('jurkom74.ru', 0, 'Law and Government > Legal', 0),
#  ('chips-journal.ru', 836, 'News and Media Publishers', 158418),
#  ('nihon-go.ru', 302, 'Arts and Entertainment > Animation and Comics', 369152),
#  ('неберитрубку.рф', 0, 'Unknown', 580395),
#  ('rannews.ru', 2941, 'News and Media Publishers', 649966),
#  ('porodadog.ru', 1025, 'Pets and Animals > Pets', 5811796),
#  ('turbopages.org', 1, 'News and Media Publishers', 34),
#  ('builderbody.ru', 20, 'Health > Nutrition Diets and Fitness', 196109),
#  ('gismeteo.ua', 2, 'Science and Education > Weather', 1722),
#  ('hh.ru', 1, 'Jobs and Career > Jobs and Employment', 525),
#  ('a42.ru', 196, 'News and Media Publishers', 38901),
#  ('electrik.info',
#   393,
#   'Computers Electronics and Technology > Programming and Developer Software',
#   221743),
#  ('lordserial.ru',
#   6662,
#   'Arts and Entertainment > Streaming and Online TV',
#   8724340),
#  ('vashtehnik.ru',
#   828,
#   'Computers Electronics and Technology > Social Media Networks',
#   2098131),
#  ('kakotlichit.ru', 116, 'Lifestyle > Jewelry and Luxury Products', 330486),
#  ('family-journal.ru', 36, 'Hobbies and Leisure > Crafts', 274102),
#  ('soundtimes.ru', 205, 'Arts and Entertainment > Music', 148839),
#  ('ampproject.org',
#   23,
#   'Computers Electronics and Technology > Programming and Developer Software',
#   11082),
#  ('sdamgia.ru', 5, 'Science and Education > Education', 2175),
#  ('namaz-time.ru', 18037, 'Arts and Entertainment', 1127178),
#  ('ea.com', 21, 'Games > Video Games Consoles and Accessories', 720),
#  ('tennis-world.ru', 1172, 'Sports > Sports - Other', 1871406),
#  ('rukniga.club',
#   310,
#   'Arts and Entertainment > Books and Literature',
#   138641),
#  ('optika-vologda.ru', 0, 'Unknown', 11985480),
#  ('gtafans.ru', 1638, 'Games > Video Games Consoles and Accessories', 522721),
#  ('eti.su',
#   750,
#   'Computers Electronics and Technology > Consumer Electronics',
#   1079963),
#  ('ru-an.info', 306, 'News and Media Publishers', 51726),
#  ('jobkadrov.ru', 70, 'Jobs and Career > Jobs and Employment', 289894),
#  ('apteka.hk', 13294, 'Health > Health - Other', 1140730),
#  ('turkseason.com',
#   102,
#   'Arts and Entertainment > Arts and Entertainment - Other',
#   164570),
#  ('windowstips.ru',
#   297,
#   'Computers Electronics and Technology > Programming and Developer Software',
#   204724),
#  ('catnames.ru', 148, 'Pets and Animals > Pets', 741170),
#  ('gorodrabot.ru', 7, 'Jobs and Career > Jobs and Employment', 12927),
#  ('informator.ua', 60, 'News and Media Publishers', 28120),
#  ('lordserial.site',
#   205,
#   'Arts and Entertainment > Streaming and Online TV',
#   94947),
#  ('отели.дети',
#   1098,
#   'Travel and Tourism > Travel and Tourism - Other',
#   1374431),
#  ('triplinks.ru',
#   3973,
#   'Travel and Tourism > Travel and Tourism - Other',
#   4700868),
#  ('kotuch.ru', 3038, 'Science and Education', 845982),
#  ('madmem.ru', 674, 'Hobbies and Leisure > Photography', 18508615),
#  ('prekrasnaja.com', 894, 'News and Media Publishers', 201172),
#  ('4s-info.ru', 2974, 'News and Media Publishers', 1138939),
#  ('awesomeworld.ru', 45, 'Science and Education > Biology', 1051484),
#  ('cian.ru', 1, 'Business and Consumer Services > Real Estate', 712),
#  ('ranobes.com', 60, 'Arts and Entertainment > Books and Literature', 23888),
#  ('livejournal.com',
#   7,
#   'Computers Electronics and Technology > Social Media Networks',
#   642),
#  ('sherlocktabak.ru',
#   97,
#   'Computers Electronics and Technology > Social Media Networks',
#   199144),
#  ('migrantmedia.ru', 6, 'Law and Government > Immigration and Visas', 395460),
#  ('books2you.ru',
#   243,
#   'Arts and Entertainment > Books and Literature',
#   178682),
#  ('telegros.ru',
#   1001,
#   'Computers Electronics and Technology > Computers Electronics and Technology - Other',
#   414220),
#  ('где-ударение.рф',
#   15,
#   'Reference Materials > Reference Materials - Other',
#   213618),
#  ('pro-spo.ru',
#   281,
#   'Computers Electronics and Technology > Computer Hardware',
#   763395),
#  ('plplayer.online', 0, 'Unknown', 4306291),
#  ('zetserial.online',
#   4422,
#   'Arts and Entertainment > Streaming and Online TV',
#   6603356),
#  ('festima.ru',
#   45,
#   'eCommerce and Shopping > eCommerce and Shopping - Other',
#   48885),
#  ('ковры-кузбасс.рф', 0, 'Unknown', 0),
#  ('40nog.ru',
#   147,
#   'eCommerce and Shopping > eCommerce and Shopping - Other',
#   182317),
#  ('oils-market.ru', 4260, 'Vehicles > Vehicles - Other', 1204355),
#  ('anynews.ru', 759, 'Food and Drink > Cooking and Recipes', 1637872),
#  ('neolove.ru', 31, 'Community and Society > Dating and Relationships', 62867),
#  ('englishsub.ru',
#   291,
#   'Arts and Entertainment > Books and Literature',
#   623765),
#  ('pristor.ru', 121, 'Arts and Entertainment > Humor', 286544),
#  ('kogda.org',
#   586,
#   'Arts and Entertainment > Streaming and Online TV',
#   211007),
#  ('sokolniki.com', 623, 'Sports > Sports - Other', 941234),
#  ('sravni24.net',
#   283,
#   'Computers Electronics and Technology > Consumer Electronics',
#   393192),
#  ('blizko.ru', 3, 'eCommerce and Shopping > Classifieds', 34302),
#  ('homechart.ru', 31, 'Home and Garden > Interior Design', 448623),
#  ('turbopages.org', 1, 'News and Media Publishers', 34),
#  ('autogrm.ru', 6843, 'Vehicles > Vehicles - Other', 1567236),
#  ('song-story.ru', 453, 'Arts and Entertainment > Music', 274921),
#  ('info-rm.com', 1115, 'News and Media Publishers', 293377),
#  ('vysokovskiy.ru', 170, 'Arts and Entertainment > Humor', 428503),
#  ('reformal.ru',
#   527,
#   'Computers Electronics and Technology > Telecommunications',
#   244300),
#  ('turbopages.org', 1, 'News and Media Publishers', 34),
#  ('allboxing.ru', 1, 'Sports > Boxing', 56714),
#  ('turbopages.org', 1, 'News and Media Publishers', 34),
#  ('turbopages.org', 1, 'News and Media Publishers', 34),
#  ('dating.ru', 22, 'Community and Society > Dating and Relationships', 55984),
#  ('prosalonoff.ru', 3800, 'Health > Health - Other', 1766381),
#  ('zhzh.info', 561, 'News and Media Publishers', 278519),
#  ('fbu3hmao.ru',
#   889,
#   'Law and Government > Law and Government - Other',
#   4240596),
#  ('getbb.ru',
#   250,
#   'Computers Electronics and Technology > Computers Electronics and Technology - Other',
#   123319),
#  ('grow-me.ru', 553, 'Home and Garden > Gardening', 1665954),
#  ('govoritnotariat.com', 390, 'Law and Government > Legal', 867391),
#  ('vseprikleim.ru',
#   204,
#   'Home and Garden > Home Improvement and Maintenance',
#   1552750),
#  ('lavnik.net',
#   3915,
#   'Computers Electronics and Technology > Computers Electronics and Technology - Other',
#   1346648),
#  ('biletyplus.by',
#   19,
#   'Travel and Tourism > Travel and Tourism - Other',
#   245347),
#  ('steprecept.ru', 475, 'Food and Drink > Cooking and Recipes', 649057),
#  ('muz-tv.ru', 126, 'Arts and Entertainment > Streaming and Online TV', 47681),
#  ('benzin-price.ru', 1337, 'Vehicles > Vehicles - Other', 685964),
#  ('cprzd.ru', 3269, 'Health > Health - Other', 1532020),
#  ('rvs.su', 5386, 'News and Media Publishers', 2691785),
#  ('onegreenweb.com', 4141, 'Science and Education > Education', 1715377),
#  ('fox-fan.tv', 60, 'Arts and Entertainment > Animation and Comics', 25153),
#  ('botlist.ru',
#   480,
#   'Computers Electronics and Technology > Computers Electronics and Technology - Other',
#   192436),
#  ('bilet-tirazh.ru', 953, 'Gambling > Lottery', 7609654),
#  ('phoneticonline.ru', 240, 'Science and Education > Education', 83240),
#  ('zornet.ru',
#   1630,
#   'Computers Electronics and Technology > Computers Electronics and Technology - Other',
#   1132340),
#  ('avtorazbor.su', 10172, 'Vehicles > Vehicles - Other', 5610588),
#  ('mxfilm.es',
#   4172,
#   'Arts and Entertainment > Streaming and Online TV',
#   5898369),
#  ('kamola.net', 0, 'Arts and Entertainment > Music', 0),
#  ('kashtankapet.ru', 0, 'Pets and Animals > Pets', 0),
#  ('turbopages.org', 1, 'News and Media Publishers', 34),
#  ('cian.ru', 1, 'Business and Consumer Services > Real Estate', 712),
#  ('ogorod-bez-hlopot.ru', 253, 'Home and Garden > Gardening', 852159),
#  ('ucoz.net',
#   8,
#   'Computers Electronics and Technology > Web Hosting and Domain Names',
#   37640),
#  ('gk-drawing.ru',
#   53,
#   'Reference Materials > Reference Materials - Other',
#   796681),
#  ('avtozapshop.ru', 780, 'Vehicles > Automotive Industry', 768071),
#  ('saint-petersburg.ru', 2137, 'News and Media Publishers', 763383),
#  ('ekaterinburgvokzal.ru',
#   354,
#   'Travel and Tourism > Ground Transportation',
#   3401076),
#  ('electrosam.ru',
#   804,
#   'Computers Electronics and Technology > Consumer Electronics',
#   979432),
#  ('rbcroyalbank.com', 7, 'Finance > Banking Credit and Lending', 3318),
#  ('superjob.ru', 5, 'Jobs and Career > Jobs and Employment', 8643),
#  ('тгкб5.рф', 20732, 'Health > Health - Other', 11102788),
#  ('serveradmin.ru',
#   610,
#   'Computers Electronics and Technology > Programming and Developer Software',
#   359282),
#  ('womanskincare.ru', 1715, 'Lifestyle > Beauty and Cosmetics', 4017856),
#  ('legav.ru', 1353, 'Arts and Entertainment > Music', 1318614),
#  ('onepleer.ru', 0, 'Unknown', 0),
#  ('zoon.ru',
#   5,
#   'Arts and Entertainment > Arts and Entertainment - Other',
#   7040),
#  ('tarifam.ru', 26836, 'News and Media Publishers', 8836939),
#  ('remkasam.ru',
#   1509,
#   'Home and Garden > Home Improvement and Maintenance',
#   9495830),
#  ('mirtesen.ru', 39, 'News and Media Publishers', 4739),
#  ('diafilmy.su', 584, 'Arts and Entertainment > Books and Literature', 644151),
#  ('turbopages.org', 1, 'News and Media Publishers', 34),
#  ('ladafakt.ru', 8981, 'Vehicles > Vehicles - Other', 4943758),
#  ('происхождение-фамилии.рф',
#   1944,
#   'Arts and Entertainment > Books and Literature',
#   1580835),
#  ('21vu.ru', 0, 'Science and Education > Education', 0),
#  ('footbolno.ru', 159, 'Sports > Soccer', 930259),
#  ('borda.ru',
#   257,
#   'Computers Electronics and Technology > Computers Electronics and Technology - Other',
#   129826),
#  ('russia-karts.ru', 145, 'Reference Materials', 338287),
#  ('mdoydetsad3.ru', 1804, 'Science and Education > Education', 1048220),
#  ('kapriz.cc', 1556, 'Hobbies and Leisure > Crafts', 7923215),
#  ('tosamara.ru', 1631, 'Computers Electronics and Technology', 254207),
#  ('wiki-games.ru',
#   2894,
#   'Games > Video Games Consoles and Accessories',
#   990177),
#  ('jobfilter.ru', 10, 'Jobs and Career > Jobs and Employment', 24627),
#  ('rzd.ru', 1, 'Travel and Tourism > Ground Transportation', 2422),
#  ('abbatstvo.ru', 0, 'Unknown', 2674349),
#  ('islamdag.ru', 66, 'Community and Society > Faith and Beliefs', 107728),
#  ('novosel.ru', 165, 'Business and Consumer Services > Real Estate', 595950),
#  ('leaky.ru', 1378, 'Lifestyle > Beauty and Cosmetics', 2620638),
#  ('sadim.guru', 0, 'Home and Garden > Gardening', 0),
#  ('tyumedia.ru', 4634, 'News and Media Publishers', 2139013),
#  ('novbu.ru', 195, 'eCommerce and Shopping > Classifieds', 884071),
#  ('doctorpiter.ru', 31, 'Health > Health - Other', 31425),
#  ('i58.ru', 108, 'eCommerce and Shopping > Classifieds', 472617),
#  ('zhongddi.com', 0, 'Unknown', 0),
#  ('yavitrina.ru',
#   50,
#   'eCommerce and Shopping > eCommerce and Shopping - Other',
#   64642),
#  ('click-or-die.ru', 205, 'News and Media Publishers', 33410),
#  ('flightradar24.com', 1, 'Vehicles > Aviation', 492),
#  ('gmstar.ru',
#   41,
#   'Reference Materials > Public Records and Directories',
#   380259),
#  ('lupzon.ru', 1311, 'Finance > Finance - Other', 2896361),
#  ('дословно.рф', 0, 'Unknown', 6173365),
#  ('pc01.ru', 82, 'eCommerce and Shopping > Classifieds', 380165),
#  ('bezformata.com', 133, 'News and Media Publishers', 26778),
#  ('лабораториябассейнов.рф', 0, 'Unknown', 16418402),
#  ('turbopages.org', 1, 'News and Media Publishers', 34),
#  ('i-air.ru',
#   5132,
#   'Computers Electronics and Technology > Computers Electronics and Technology - Other',
#   2358123),
#  ('yagazeta.com', 12452, 'Arts and Entertainment', 2796759),
#  ('decorwind.ru', 288, 'Home and Garden > Interior Design', 2300314),
#  ('net.ru',
#   10612,
#   'Computers Electronics and Technology > Computers Electronics and Technology - Other',
#   5712922),
#  ('gornovosti.ru', 1095, 'News and Media Publishers', 272574),
#  ('ticketshop.ru',
#   3194,
#   'Computers Electronics and Technology > Computers Electronics and Technology - Other',
#   1629979),
#  ('eagleplatform.com', 11140, 'News and Media Publishers', 7463753),
#  ('infox.sg', 28, 'News and Media Publishers', 2893),
#  ('beauty-med-clinic.ru', 0, 'Unknown', 0),
#  ('vkzodiac.ru', 2624, 'News and Media Publishers', 763125),
#  ('oventilyatsii.ru',
#   3988,
#   'Heavy Industry and Engineering > Construction and Maintenance',
#   3171838),
#  ('podrobno.uz', 5, 'News and Media Publishers', 50716),
#  ('saechka.ru', 85, 'Food and Drink > Cooking and Recipes', 237554),
#  ('sunnyhotel.ru',
#   111,
#   'Travel and Tourism > Travel and Tourism - Other',
#   193473),
#  ('playsector.ru',
#   351,
#   'Games > Video Games Consoles and Accessories',
#   102246),
#  ('mfd.ru', 9, 'Finance > Investing', 34130),
#  ('travelbelka.ru',
#   144,
#   'Travel and Tourism > Travel and Tourism - Other',
#   268031),
#  ('shkolala.ru', 2507, 'Science and Education > Education', 1234594),
#  ('manbe.ru', 7995, 'Health > Health - Other', 1064783),
#  ('move.ru', 10, 'Home and Garden', 19941),
#  ('content-watch.ru',
#   44,
#   'Science and Education > Science and Education - Other',
#   196633),
#  ('visualrian.ru', 4088, 'News and Media Publishers', 1808134),
#  ('usadba-jazz.ru', 9685, 'Arts and Entertainment > Music', 12736354),
#  ('historic.ru', 12, 'Science and Education > History', 396552),
#  ('sovjen.ru', 7412, 'Arts and Entertainment', 1610007),
#  ('vseonauke.com', 1945, 'News and Media Publishers', 523602),
#  ('vokrugsveta.tv', 0, 'Gambling > Lottery', 0),
#  ('lessday.ru', 342, 'Lifestyle > Beauty and Cosmetics', 691297),
#  ('optisalt.su', 2469, 'Health > Health - Other', 1158003),
#  ('2map.su', 92, 'Reference Materials > Maps', 533089),
#  ('sibnet.ru', 90, 'News and Media Publishers', 12825),
#  ('sochi-express.ru', 2523, 'News and Media Publishers', 972975),
#  ('adobe.com',
#   6,
#   'Computers Electronics and Technology > Computers Electronics and Technology - Other',
#   125),
#  ('somon.tj', 1, 'eCommerce and Shopping > Classifieds', 28063),
#  ('mail.ru', 1, 'Computers Electronics and Technology > Email', 31),
#  ('yandex.net',
#   7,
#   'Computers Electronics and Technology > Search Engines',
#   4634),
#  ('trontv.com',
#   96,
#   'Computers Electronics and Technology > File Sharing and Hosting',
#   12768),
#  ('krasrab.ru', 1675, 'News and Media Publishers', 437161),
#  ('picsy.ru', 207, 'Hobbies and Leisure > Photography', 661268),
#  ('ot-boli.ru', 4883, 'Health > Health - Other', 2378873),
#  ('serieslife.ru', 0, 'Unknown', 0),
#  ('alloy.ru',
#   386,
#   'eCommerce and Shopping > eCommerce and Shopping - Other',
#   402549),
#  ('gmstar.ru',
#   41,
#   'Reference Materials > Public Records and Directories',
#   380259),
#  ('gtn-pravda.ru', 2251, 'News and Media Publishers', 847702),
#  ('vzlomannye-igry-dlya-android.net',
#   2503,
#   'Games > Video Games Consoles and Accessories',
#   777336),
#  ('funik.ru', 71, 'Arts and Entertainment > Humor', 172008),
#  ('imenada.ru', 7813, 'Arts and Entertainment', 999640),
#  ('travelask.ru', 9, 'Travel and Tourism > Travel and Tourism - Other', 16542),
#  ('doctorberezovska.com', 52, 'Health > Childrens Health', 449160),
#  ('com.ua',
#   4553,
#   'Computers Electronics and Technology > Computers Electronics and Technology - Other',
#   6420396),
#  ('dizajnnogtej.com', 0, 'Lifestyle > Beauty and Cosmetics', 0),
#  ('4hw.ru',
#   484,
#   'Computers Electronics and Technology > Telecommunications',
#   602809),
#  ('remo-blog.ru',
#   457,
#   'Home and Garden > Home Improvement and Maintenance',
#   3110728),
#  ('rusdate.net',
#   37,
#   'Community and Society > Dating and Relationships',
#   45522),
#  ('appvisor.ru',
#   745,
#   'Computers Electronics and Technology > Computers Electronics and Technology - Other',
#   224032),
#  ('balkonidea.ru',
#   648,
#   'Home and Garden > Home Improvement and Maintenance',
#   4750168),
#  ('tehclub.site', 25, 'Vehicles > Aviation', 474714),
#  ('iqoswiki.ru',
#   1704,
#   'Computers Electronics and Technology > Social Media Networks',
#   1359264),
#  ('wordexpert.ru',
#   2335,
#   'Computers Electronics and Technology > Programming and Developer Software',
#   1222772),
#  ('transport-online.ru', 371, 'Reference Materials > Maps', 4454669),
#  ('mk.ru', 6, 'News and Media Publishers', 470),
#  ('4lapki.com', 550, 'Pets and Animals > Pets', 1062387),
#  ('crack-portal.ru',
#   786,
#   'Computers Electronics and Technology > Computers Electronics and Technology - Other',
#   297168),
#  ('turbopages.org', 1, 'News and Media Publishers', 34),
#  ('tltgorod.ru', 1085, 'News and Media Publishers', 313776),
#  ('givewhereyoulivehamptons.org',
#   1492,
#   'Home and Garden > Home Improvement and Maintenance',
#   10703653),
#  ('turbopages.org', 1, 'News and Media Publishers', 34),
#  ('turbopages.org', 1, 'News and Media Publishers', 34),
#  ('rabotunaidu.ru', 1203, 'Jobs and Career > Jobs and Employment', 5832180),
#  ('ekranka.tv',
#   1741,
#   'Arts and Entertainment > Streaming and Online TV',
#   529786),
#  ('clubdatsun.ru', 11080, 'Vehicles > Vehicles - Other', 6048134),
#  ('mashintop.ru', 1465, 'Vehicles > Vehicles - Other', 681399),
#  ('hamster.ru', 268, 'Pets and Animals > Pets', 1103602),
#  ('adresa-telefony.ru',
#   12,
#   'Reference Materials > Public Records and Directories',
#   90647),
#  ('presidentclinic.ru', 5194, 'Health > Health - Other', 2626603),
#  ('dogcatdog.ru', 4607, 'Science and Education > Education', 3307497),
#  ('gameinfo.io', 236, 'Games > Video Games Consoles and Accessories', 14863),
#  ('bankgid.com', 1207, 'News and Media Publishers', 354804),
#  ('goodman.ru', 1038, 'Food and Drink > Food and Drink - Other', 1290191),
#  ('robdom.ru', 515, 'Home and Garden > Interior Design', 5609510),
#  ('crediti-bez-problem.ru',
#   1526,
#   'Finance > Financial Planning and Management',
#   6301847),
#  ('eagleplatform.com', 11140, 'News and Media Publishers', 7463753),
#  ('batnorton.com', 246, 'Lifestyle > Fashion and Apparel', 308262),
#  ('autoexpert.vc', 3130, 'Vehicles > Vehicles - Other', 1599002),
#  ('bazon.site',
#   3067,
#   'Computers Electronics and Technology > Computers Electronics and Technology - Other',
#   1559684),
#  ('bezformata.com', 133, 'News and Media Publishers', 26778),
#  ('sport1tv.ru', 65, 'Sports > Sports - Other', 148788),
#  ('volsiz.ru', 589, 'Games > Video Games Consoles and Accessories', 38160),
#  ('lukoilazs.ru', 6180, 'Vehicles > Vehicles - Other', 2796961),
# ...
#  ('hh.ru', 1, 'Jobs and Career > Jobs and Employment', 525),
#  ('kinoafisha.info',
#   5,
#   'Arts and Entertainment > Streaming and Online TV',
#   1877),
#  ('lordfilm.lu', 8, 'Arts and Entertainment > Streaming and Online TV', 2235),
#  ('strbsu.ru', 936, 'Science and Education > Education', 469993),
#  ('екатеринбург.рф', 71, 'Science and Education > Education', 32512),
#  ('huntland.ru', 1101, 'Vehicles > Vehicles - Other', 670918),
#  ('lordfilm.pet',
#   6356,
#   'Arts and Entertainment > Streaming and Online TV',
#   10337463),
#  ('yandex.net',
#   7,
#   'Computers Electronics and Technology > Search Engines',
#   4634),
#  ('abhaziapro.ru',
#   4890,
#   'Travel and Tourism > Travel and Tourism - Other',
#   6390053),
#  ('nauchniestati.ru', 336, 'Science and Education > Education', 124389),
#  ('hh.ru', 1, 'Jobs and Career > Jobs and Employment', 525),
#  ('turbopages.org', 1, 'News and Media Publishers', 34),
#  ('ischempodarok.ru', 286, 'Lifestyle > Gifts and Flowers', 1561338),
#  ('zoon.ru',
#   5,
#   'Arts and Entertainment > Arts and Entertainment - Other',
#   7040),
#  ('rus.team', 977, 'News and Media Publishers', 182998),
#  ('msk-rabota.ru', 0, 'Jobs and Career > Jobs and Employment', 0),
#  ('mangahub.ru', 12, 'Arts and Entertainment > Animation and Comics', 10639),
#  ('rodina.news', 9192, 'News and Media Publishers', 3056294),
#  ('spb-guide.ru',
#   155,
#   'Travel and Tourism > Travel and Tourism - Other',
#   273701),
#  ('krdgp25.ru', 2684, 'Health > Health - Other', 528848),
#  ('minutamami.ru', 1571, 'News and Media Publishers', 415582),
#  ('vashdoctorclinic.ru', 2461, 'Health > Health - Other', 846006),
#  ('mobile-testing.ru',
#   222,
#   'Finance > Financial Planning and Management',
#   351481),
#  ('vnickname.ru', 740, 'Games > Video Games Consoles and Accessories', 204904),
#  ('audio-books.su',
#   52,
#   'Arts and Entertainment > Books and Literature',
#   34820),
#  ('primorye.ru', 379, 'News and Media Publishers', 85993),
#  ('ideaprog.download',
#   14370,
#   'Computers Electronics and Technology > Programming and Developer Software',
#   6509125),
#  ('igis.ru', 25, 'Reference Materials > Maps', 145595),
#  ('turbopages.org', 1, 'News and Media Publishers', 34),
#  ('pollianna-med.ru', 0, 'Health > Health - Other', 0),
#  ('atlastkani.ru',
#   2104,
#   'eCommerce and Shopping > eCommerce and Shopping - Other',
#   1310871),
#  ('vikings.help', 956, 'Games > Video Games Consoles and Accessories', 143893),
#  ('compumir.ru',
#   35,
#   'Computers Electronics and Technology > Consumer Electronics',
#   87641),
#  ('sweet-street.ru', 5, 'Food and Drink > Cooking and Recipes', 215895),
#  ('vseobzorko.ru', 96, 'eCommerce and Shopping > Classifieds', 322717),
#  ('stomatologija.su', 35, 'Health > Dentist and Dental Services', 928837),
#  ('ria.com', 3, 'eCommerce and Shopping > Marketplace', 1464),
#  ('vipik.net', 11544, 'Arts and Entertainment > Music', 1664536),
#  ('loveffect.ru',
#   256,
#   'Community and Society > Dating and Relationships',
#   1200908),
#  ('2queens.ru', 1165, 'Arts and Entertainment > Books and Literature', 766525),
#  ('compumir.ru',
#   35,
#   'Computers Electronics and Technology > Consumer Electronics',
#   87641),
#  ('newsorel.ru', 463, 'News and Media Publishers', 107979),
#  ('rockperson.ru', 953, 'Arts and Entertainment > Music', 933301),
#  ('klassikaknigi.info',
#   305,
#   'Arts and Entertainment > Books and Literature',
#   119120),
#  ('turbopages.org', 1, 'News and Media Publishers', 34),
#  ('tsargrad.tv', 14, 'News and Media Publishers', 1641),
#  ('academic.ru',
#   6,
#   'Reference Materials > Dictionaries and Encyclopedias',
#   11026),
#  ('solerno.ru', 3696, 'Health > Health - Other', 1736585),
#  ('mirnov.ru', 1703, 'News and Media Publishers', 432015),
#  ('fly-inform.ru', 148, 'Travel and Tourism > Air Travel', 880359),
#  ('superjob.ru', 5, 'Jobs and Career > Jobs and Employment', 8643),
#  ('transfiles.ru',
#   739,
#   'Computers Electronics and Technology > Computers Electronics and Technology - Other',
#   338323),
#  ('inetvl.ru',
#   156,
#   'Computers Electronics and Technology > Telecommunications',
#   232363),
#  ('biletix.ru', 48, 'Travel and Tourism > Air Travel', 229794),
#  ('regtorg.ru', 111, 'eCommerce and Shopping', 84891),
#  ('lyrsense.com', 30, 'Arts and Entertainment > Music', 19011),
#  ('pesenok.ru', 386, 'Arts and Entertainment > Music', 316601),
#  ('domovod.guru', 1916, 'Pets and Animals > Pets', 8607557),
#  ('pervo66.ru', 2962, 'News and Media Publishers', 1170248),
#  ('livesport.ru', 29, 'Sports > Sports - Other', 35594),
#  ('willandwin.ru', 224, 'Health > Nutrition Diets and Fitness', 1322659),
#  ('felomena.com', 25, 'Community and Society > Faith and Beliefs', 29106),
#  ('fandom.com',
#   1,
#   'Arts and Entertainment > Arts and Entertainment - Other',
#   50),
#  ('nationmagazine.ru', 4642, 'News and Media Publishers', 1935617),
#  ('autotopik.ru', 188, 'Vehicles > Vehicles - Other', 186603),
#  ('saucyintruder.org',
#   1620,
#   'Heavy Industry and Engineering > Construction and Maintenance',
#   1449692),
#  ('automotocity.com', 2889, 'Vehicles > Vehicles - Other', 1365959),
#  ('new-magazine.ru', 1301, 'News and Media Publishers', 340250),
#  ('epcdata.ru', 444, 'Vehicles > Automotive Industry', 683790),
#  ('i58.ru', 108, 'eCommerce and Shopping > Classifieds', 472617),
#  ('ampproject.org',
#   23,
#   'Computers Electronics and Technology > Programming and Developer Software',
#   11082),
#  ('priority-auto.ru', 1118, 'Vehicles > Vehicles - Other', 707577),
#  ('turbopages.org', 1, 'News and Media Publishers', 34),
#  ('data-vyhoda.com',
#   1326,
#   'Arts and Entertainment > Streaming and Online TV',
#   336674),
#  ('okuzove.ru', 5293, 'Vehicles > Vehicles - Other', 2444803),
#  ('domkino.tv', 571, 'News and Media Publishers', 132903),
#  ('turbopages.org', 1, 'News and Media Publishers', 34),
#  ('agryz-rt.ru', 5269, 'News and Media Publishers', 2566638),
#  ('reverso.net',
#   2,
#   'Reference Materials > Dictionaries and Encyclopedias',
#   218),
#  ('kakpishu.ru', 3906, 'Science and Education', 1447027),
#  ('sotoguide.ru',
#   70,
#   'Computers Electronics and Technology > Consumer Electronics',
#   118572),
#  ('zhenskiyray.ru', 1090, 'Lifestyle > Beauty and Cosmetics', 6276441),
#  ('rusavtobus.ru',
#   182,
#   'Business and Consumer Services > Shipping and Logistics',
#   840364),
#  ('ria.ru', 4, 'News and Media Publishers', 290),
#  ('2karandasha.ru', 271, 'Science and Education > Education', 93240),
#  ('i-fakt.ru',
#   141,
#   'Science and Education > Science and Education - Other',
#   532087),
#  ('avtoudostoverenie.ru', 5804, 'Vehicles > Vehicles - Other', 2942644),
#  ('gmstar.ru',
#   41,
#   'Reference Materials > Public Records and Directories',
#   380259),
#  ('eagleplatform.com', 11140, 'News and Media Publishers', 7463753),
#  ('nodevice.com',
#   178,
#   'Computers Electronics and Technology > Programming and Developer Software',
#   94725),
#  ('mail.ru', 1, 'Computers Electronics and Technology > Email', 31),
#  ('myrail.ru', 319, 'Law and Government > Legal', 1206827),
#  ('basarunet.org',
#   4730,
#   'Computers Electronics and Technology > Programming and Developer Software',
#   1874214),
#  ('royal.ru',
#   356,
#   'Heavy Industry and Engineering > Construction and Maintenance',
#   650551),
#  ('muzmart.com', 607, 'Arts and Entertainment > Music', 649896),
#  ('atuin.ru',
#   1936,
#   'Computers Electronics and Technology > Computers Electronics and Technology - Other',
#   833675),
#  ('1drevo.ru',
#   2523,
#   'Heavy Industry and Engineering > Construction and Maintenance',
#   2087385),
#  ('cadelta.ru', 1699, 'Computers Electronics and Technology', 213046),
#  ('avito.ru', 1, 'eCommerce and Shopping > Classifieds', 72),
#  ('anwap.pub', 0, 'Arts and Entertainment > Streaming and Online TV', 0),
#  ('mytischiriamo.ru', 3037, 'News and Media Publishers', 1039631),
#  ('shhyolkovo.ru', 1271, 'Law and Government > Government', 2086575),
#  ('snabstroyteh.ru',
#   4295,
#   'Heavy Industry and Engineering > Construction and Maintenance',
#   2810683),
#  ('lets-play.by',
#   1191,
#   'Games > Video Games Consoles and Accessories',
#   308783),
#  ('vm.ru', 136, 'News and Media Publishers', 24506),
#  ('turbopages.org', 1, 'News and Media Publishers', 34),
#  ('ольгапратура.рф', 0, 'Unknown', 8315670),
#  ('rybalkashop.ru',
#   60,
#   'eCommerce and Shopping > eCommerce and Shopping - Other',
#   81803),
#  ('metal4u.ru',
#   275,
#   'Heavy Industry and Engineering > Metals and Mining',
#   5505029),
#  ('bezformata.com', 133, 'News and Media Publishers', 26778),
#  ('chevroletov.ru', 15724, 'Vehicles > Vehicles - Other', 7778600),
#  ('askdd.xyz',
#   346,
#   'Law and Government > Law and Government - Other',
#   1532471),
#  ('zakon.ru', 11, 'Law and Government > Legal', 49969),
#  ('katuna.ru', 1449, 'Food and Drink > Cooking and Recipes', 3900890),
#  ('273-фз.рф', 8854, 'Science and Education > Education', 6103355),
#  ('shaiba.kz', 7, 'Sports > Sports - Other', 97069),
#  ('doseng.org', 498, 'Arts and Entertainment > Humor', 1112226),
#  ('livejournal.com',
#   7,
#   'Computers Electronics and Technology > Social Media Networks',
#   642),
#  ('nozhik.online',
#   790,
#   'eCommerce and Shopping > eCommerce and Shopping - Other',
#   784701),
#  ('translate.ru', 197, 'Computers Electronics and Technology', 21654),
#  ('lostseries.net', 0, 'Arts and Entertainment > Streaming and Online TV', 0),
#  ('vopros-pdd.info', 0, 'Vehicles > Vehicles - Other', 0),
#  ('turbopages.org', 1, 'News and Media Publishers', 34),
#  ('autonet.ru', 425, 'Vehicles > Automotive Industry', 296379),
#  ('netbynet.ru',
#   228,
#   'Computers Electronics and Technology > Telecommunications',
#   277300),
#  ('dreamworlds.ru',
#   1707,
#   'Arts and Entertainment > Books and Literature',
#   2661023),
#  ('tlgbot.ru',
#   854,
#   'Computers Electronics and Technology > Programming and Developer Software',
#   462056),
#  ('otdelkasten.com',
#   496,
#   'Home and Garden > Home Improvement and Maintenance',
#   3352420),
#  ('tarotmagic.ru', 744, 'Community and Society > Faith and Beliefs', 1257965),
#  ('propionix.ru', 1207, 'Health > Health - Other', 413730),
#  ('zelv.ru', 1610, 'News and Media Publishers', 452895),
#  ('lordfilmx.biz',
#   3493,
#   'Arts and Entertainment > Streaming and Online TV',
#   4650349),
#  ('екатеринбург.рф', 71, 'Science and Education > Education', 32512),
#  ('prozarplaty.ru', 2291, 'News and Media Publishers', 847569),
#  ('kpcdn.net', 164, 'Arts and Entertainment > Humor', 406413),
#  ('zarplata.ru', 6, 'Jobs and Career > Jobs and Employment', 12436),
#  ('ampproject.org',
#   23,
#   'Computers Electronics and Technology > Programming and Developer Software',
#   11082),
#  ('fansitemi.ru',
#   537,
#   'Computers Electronics and Technology > Consumer Electronics',
#   755125),
#  ('skwstat.ru',
#   22661,
#   'Computers Electronics and Technology > Programming and Developer Software',
#   14150110),
#  ('blizko.ru', 3, 'eCommerce and Shopping > Classifieds', 34302),
#  ('andrmed1.ru', 0, 'Health > Health - Other', 0),
#  ('autofakty.com', 2359, 'Vehicles > Vehicles - Other', 1418534),
#  ('vikingi-online.info',
#   455,
#   'Arts and Entertainment > Streaming and Online TV',
#   131313),
#  ('alvitrading.ru', 487, 'Health > Pharmacy', 4447339),
#  ('uramaks.com',
#   12414,
#   'Computers Electronics and Technology > Computers Electronics and Technology - Other',
#   3965921),
#  ('stylekrov.ru',
#   5852,
#   'Heavy Industry and Engineering > Construction and Maintenance',
#   3211506),
#  ('mp3xa.fm', 569, 'Arts and Entertainment > Music', 610076),
#  ('yarmarka-mos.ru',
#   891,
#   'Arts and Entertainment > Books and Literature',
#   1356421),
#  ('anekdotov.net', 8, 'Arts and Entertainment > Humor', 17065),
#  ('turbopages.org', 1, 'News and Media Publishers', 34),
#  ('osnova35.ru', 7729, 'Vehicles > Vehicles - Other', 4177271),
#  ('instagramis.ru',
#   582,
#   'Arts and Entertainment > Arts and Entertainment - Other',
#   281189),
#  ('turbopages.org', 1, 'News and Media Publishers', 34),
#  ('bb.lv', 7, 'News and Media Publishers', 26544),
#  ('ekabu.ru',
#   63,
#   'Arts and Entertainment > Arts and Entertainment - Other',
#   58379),
#  ('tsu.ru', 133, 'Science and Education > Education', 42038),
#  ('mcko.ru', 73, 'Science and Education > Education', 33621),
#  ('sterlitamak.ru', 11097, 'News and Media Publishers', 7463636),
#  ('rg.ru', 18, 'News and Media Publishers', 1899),
#  ('novinkimebeli.ru',
#   4835,
#   'Home and Garden > Home and Garden - Other',
#   1982838),
#  ('avrorra.com', 991, 'Lifestyle > Beauty and Cosmetics', 1002547),
#  ('cathedral.ru',
#   304,
#   'Science and Education > Libraries and Museums',
#   1660192),
#  ('turbopages.org', 1, 'News and Media Publishers', 34),
#  ('turbopages.org', 1, 'News and Media Publishers', 34),
#  ('lordfilm.lu', 8, 'Arts and Entertainment > Streaming and Online TV', 2235),
#  ('pstationblog.ru', 490, 'Games > Games - Other', 897895),
#  ('gamebomb.ru', 26, 'Games > Games - Other', 35129),
#  ('cian.ru', 1, 'Business and Consumer Services > Real Estate', 712),
#  ('47news.ru', 195, 'News and Media Publishers', 39543),
#  ('курганзапчасти.рф', 0, 'Unknown', 0),
#  ('ampproject.org',
#   23,
#   'Computers Electronics and Technology > Programming and Developer Software',
#   11082),
#  ('bukvaprava.ru', 274, 'Law and Government > Legal', 1101552),
#  ('ppt.ru', 270, 'News and Media Publishers', 57602),
#  ('anyrel-blog.ru',
#   7884,
#   'Games > Video Games Consoles and Accessories',
#   4759433),
#  ('u-ksyushi.ru', 2201, 'Health > Health - Other', 900872),
#  ('primechaniya.ru', 1992, 'News and Media Publishers', 596421),
#  ('russiancouncil.ru',
#   86,
#   'Law and Government > Law and Government - Other',
#   289153),
#  ('souspark.ru', 89, 'Food and Drink > Cooking and Recipes', 55223),
#  ('oszone.net',
#   198,
#   'Computers Electronics and Technology > Computers Electronics and Technology - Other',
#   86396),
#  ('ptici.info', 6373, 'Science and Education', 1355193),
#  ('gorodrabot.ru', 7, 'Jobs and Career > Jobs and Employment', 12927),
#  ('glavbukh.ru', 12, 'Finance > Finance - Other', 18187),
#  ('mirkvartir.ru', 4, 'Business and Consumer Services > Real Estate', 16032),
#  ('kraftltd.com',
#   2457,
#   'eCommerce and Shopping > eCommerce and Shopping - Other',
#   2390638),
#  ('cian.ru', 1, 'Business and Consumer Services > Real Estate', 712),
#  ('fis.ru', 55, 'eCommerce and Shopping > Classifieds', 261233),
#  ('2022g.ru', 271, 'Law and Government > Government', 322047),
#  ('salyat.com', 165, 'Community and Society > Faith and Beliefs', 235733),
#  ('turbopages.org', 1, 'News and Media Publishers', 34),
#  ('sports.ru', 2, 'Sports > Sports - Other', 701),
#  ('famt.ru', 244, 'Community and Society > Faith and Beliefs', 321936),
#  ('vkrasnoznamenske.ru', 211, 'Finance > Finance - Other', 433170),
#  ('exspertrieltor.ru', 311, 'Law and Government > Legal', 1240492),
#  ('turbopages.org', 1, 'News and Media Publishers', 34),
#  ('turbopages.org', 1, 'News and Media Publishers', 34),
#  ('yoip.ru', 22, 'Reference Materials > Maps', 101874),
#  ('gg12.ru', 3612, 'News and Media Publishers', 753565),
#  ('e-ipar.ru', 84, 'Finance > Accounting and Auditing', 561071),
#  ('srrb.ru', 3, 'Sports > Martial Arts', 68062),
#  ('7themes.su',
#   179,
#   'Computers Electronics and Technology > Programming and Developer Software',
#   109222),
#  ('7fon.org',
#   298,
#   'Computers Electronics and Technology > Computers Electronics and Technology - Other',
#   71999),
#  ('tc-nabegovoy.ru', 418, 'Lifestyle > Gifts and Flowers', 2335359),
#  ('cian.ru', 1, 'Business and Consumer Services > Real Estate', 712),
#  ('how2get.ru', 867, 'Law and Government', 723315),
#  ('chelovekizakon.ru', 400, 'Law and Government > Legal', 1521199),
#  ('detalibt.ru',
#   3164,
#   'Computers Electronics and Technology > Consumer Electronics',
#   4513249),
#  ('brelki-avto.ru', 9826, 'Vehicles > Vehicles - Other', 5428864),
#  ('vesiskitim.ru', 365, 'News and Media Publishers', 78213),
#  ('radiovera.ru', 78, 'Community and Society > Faith and Beliefs', 145003),
#  ('cian.ru', 1, 'Business and Consumer Services > Real Estate', 712),
#  ('gtn.ru', 5257, 'Computers Electronics and Technology', 743396),
#  ('testsmart.ru', 3689, 'Computers Electronics and Technology', 522245),
#  ('of-crimea.ru',
#   4552,
#   'Travel and Tourism > Travel and Tourism - Other',
#   5740886),
#  ('kashira.ru', 2948, 'News and Media Publishers', 1166947),
#  ('kupond.ru', 5224, 'Computers Electronics and Technology', 730661),
#  ...]

# %% [markdown]
# ## Пример информации о сайте

# %%
info[2]
# Out:
# ('med-tutorial.ru',
#  'med-tutorial.ru is ranked #1925 in the Health > Health - Other category and #737413 Globally according to February 2023 data. Get the full med-tutorial.ru Analytics and market share drilldown here',
#  "med-tutorial.ru Audience DemographicsAudience composition can reveal a site's current market share across various audiences. med-tutorial.ru's audience is 35.82% male and 64.18% female. The largest age group of visitors are 25 - 34 year olds (Desktop).  Age DistributionGender DistributionFemale64.18%Male35.82%",
#  False)

# %% [markdown]
# ## Выделение информации о поле

# %%
ismale = []
err_cnts = 0
for x in tqdm(info):
    try:
        ismale.append(float(x[2].split('audience is ')[-1].split('%')[0]))
    except Exception as e:
        err_cnts += 1
        ismale.append(50.)
err_cnts
# Out:
#   0%|          | 0/17923 [00:00<?, ?it/s]
# 2163

# %% [markdown]
# ## Выделение информации о возрасте, мода

# %%
age_group = []
err_cnts = 0
for x in tqdm(info):
    try:
        age = str(x[2].split(
            'The largest age group of visitors are '
        )[-1].split(' year olds')[0]).replace(' ', '')
        assert len(age) < 10
        age_group.append(age)
    except Exception as e:
        err_cnts += 1
        age_group.append('25-34')
err_cnts
# Out:
#   0%|          | 0/17923 [00:00<?, ?it/s]
# 2163

# %% [markdown]
# ## Выделение информации о возрасте, гистограма

# %%
age_probs = []
err_cnts = 0
for x in tqdm(info):
    try:
        probs =  list(map(float, 
            x[2].split('Highcharts 10.3.2')[-1].split('18 - 24')[0].split('%')[:-1]
                         ))
        assert len(probs) == 6
        age_probs.append(
           probs
        )
    except Exception as e:
        err_cnts += 1
        age_probs.append([0]*6)
age_probs = np.array(age_probs)
age_probs[age_probs[:, 0]==0] = age_probs[np.unique(age_probs.nonzero()[0])].mean(axis=0)
err_cnts
# Out:
#   0%|          | 0/17923 [00:00<?, ?it/s]
# 16651

# %% [markdown]
# ## Векторизация категорий

# %%
topics = [x[2] for x in meta_info]

topics_cbag = CountVectorizer(min_df=10).fit_transform(pd.Series(topics))
topics_cbag
# Out:
# <17923x187 sparse matrix of type '<class 'numpy.int64'>'
# 	with 72707 stored elements in Compressed Sparse Row format>

# %% [markdown]
# ## Векторизация возраста и пола

# %%
with gzip.open('files/url_host_cbag_v2.pickle.gz', 'rb') as f:
    datamap = pickle.load(f)
datamap
# Out:
# {'data': <415317x199684 sparse matrix of type '<class 'numpy.uint32'>'
#  	with 32277669 stored elements in Compressed Sparse Row format>,
#  'uids': array([     4,     16,     18, ..., 415276, 415288, 415293])}

# %%
map_df = pd.read_csv('auxilary/url_host_mapper_v2.tsv.gz', sep='\t')

reindex = \
pd.DataFrame(
    dict(url_host=[x[0] for x in info])
        ).merge(map_df).drop_duplicates('url_host').url_host_idx.values.copy()

# %%
all_data = datamap['data'][:, reindex]
all_data_sqrt = csr_matrix((all_data.data**0.25, all_data.nonzero()),
                     shape=all_data.shape,
                     dtype=np.float32)

sex_score = TfidfTransformer(sublinear_tf=True).fit_transform(
        all_data_sqrt
).dot(np.array(ismale)-50.)
sex_score = sex_score/sex_score.std()/3.

# %%
topics_score = TfidfTransformer(sublinear_tf=True).fit_transform(
        all_data_sqrt
).dot(topics_cbag.toarray() - topics_cbag.toarray().mean(axis=0))
topics_score = Normalizer().fit_transform(topics_score)
topics_score = topics_score / topics_score.std(axis=0)
topics_score = np.clip(topics_score, -5, 5)
topics_score
# Out:
# array([[-1.11097803,  3.28295232, -0.41728786, ...,  0.87511175,
#         -0.43044166, -0.50503614],
#        [-0.86775558, -0.18287171, -0.32593252, ..., -0.56362885,
#         -0.33620661, -0.39447038],
#        [-0.28819117, -0.21084747, -0.37579375, ...,  0.1942539 ,
#         -0.38763957, -0.45481655],
#        ...,
#        [-0.36784412, -0.07751985, -0.13816375, ..., -0.23892391,
#         -0.14251896, -0.16721714],
#        [-0.44771531, -0.09435199, -0.16816369, ..., -0.29080224,
#         -0.17346457, -0.20352555],
#        [-0.37209047, -0.07841473, -0.13975869, ..., -0.24168203,
#         -0.14416418, -0.16914748]])

# %%
top_rank = \
    np.array([x[1] for x in meta_info]).argsort().argsort()/len(meta_info) - 0.5
ranking_score = TfidfTransformer(sublinear_tf=True).fit_transform(
        all_data_sqrt
).dot(np.array(top_rank))
ranking_score = ranking_score/ranking_score.std()/3.

# %%
all_rank = \
    np.array([x[3] for x in meta_info]).argsort().argsort()/len(meta_info) - 0.5
ranking_score2 = TfidfTransformer(sublinear_tf=True).fit_transform(
        all_data_sqrt
).dot(np.array(all_rank))
ranking_score2 = ranking_score2/ranking_score2.std()/3.

# %%
age_score = \
TfidfTransformer(sublinear_tf=True).fit_transform(
        all_data_sqrt
).dot(pd.get_dummies(age_group).values[:, :-1])
age_score = Normalizer().fit_transform(age_score)

# %%
age_score2 = \
TfidfTransformer(sublinear_tf=True).fit_transform(
        all_data_sqrt
).dot(age_probs - age_probs.mean(axis=0))
age_score2 = Normalizer().fit_transform(age_score2)
age_score2
# Out:
# array([[ 0.75102459,  0.29370035, -0.28601228, -0.47237416, -0.18653866,
#         -0.09982549],
#        [ 0.54642513,  0.46524543,  0.11195845, -0.32237975, -0.5554918 ,
#         -0.24480959],
#        [ 0.65947033,  0.45207254, -0.19339324, -0.40583681, -0.37330662,
#         -0.13880564],
#        ...,
#        [ 0.51839175,  0.00990952, -0.70853066, -0.37718109,  0.29465338,
#          0.00836116],
#        [ 0.85686198,  0.09953513, -0.29246893, -0.30998074, -0.253182  ,
#         -0.10076234],
#        [ 0.51839175,  0.00990952, -0.70853066, -0.37718109,  0.29465338,
#          0.00836116]])

# %% [markdown]
# ## Конкатенация признаков SimWeb

# %%
simweb_scores = \
np.concatenate([sex_score[:, None],
                topics_score,
                ranking_score[:, None],
                ranking_score2[:, None],
                age_score,
                age_score2
                ], axis=1)

simweb_scores
# Out:
# array([[ 0.43295181, -1.11097803,  3.28295232, ..., -0.47237416,
#         -0.18653866, -0.09982549],
#        [ 0.83631993, -0.86775558, -0.18287171, ..., -0.32237975,
#         -0.5554918 , -0.24480959],
#        [ 1.05223869, -0.28819117, -0.21084747, ..., -0.40583681,
#         -0.37330662, -0.13880564],
#        ...,
#        [ 0.13573071, -0.36784412, -0.07751985, ..., -0.37718109,
#          0.29465338,  0.00836116],
#        [ 0.26681284, -0.44771531, -0.09435199, ..., -0.30998074,
#         -0.253182  , -0.10076234],
#        [-0.01174745, -0.37209047, -0.07841473, ..., -0.37718109,
#          0.29465338,  0.00836116]])

# %% [markdown]
# ## Сохранение признаков

# %%
with gzip.open('auxilary/simweb_domain.pickle.gz', 'wb') as f:
    pickle.dump(simweb_scores, f, protocol=-1)
